# %% [markdown]
# # REST Interface
# ## Introduction
# This notebook launches the REST interface, which evaluates a method system based on BRAT annotations.
#
# ### Prerequisites
# - Clone the repository:
#   ```bash
#   git clone https://github.com/GuiGuiBazin/REST-interface.git
#   ```
# - Install the dependencies:
#   ```bash
#   pip install -r requirements.txt
#   ```
# - Download the required spaCy model:
#   ```bash
#   python -m spacy download fr_core_news_sm
#   ```
#
# This notebook assumes that dependencies are correctly installed and that the modules are accessible in the `REST_modules` folder.

# %% [markdown]
# ## I - Imports

# %%
# Import necessary modules
import nltk
# %load_ext autoreload
# %autoreload 2
from REST_modules import *
# Out:
# d:\1_CLEM\ESIEE SCHOOL\PARCOURS RECHERCHE\Le juste usage des LLM et méthode NLP en cancélorlogie\DuraXELL\.venv\Lib\site-packages\torch\cuda\__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %% [markdown]
# ## II - Launch the REST Interface

# %%
# Launch the REST interface
Launch_REST()
# Out:
# DEBUG: Running updated calculate_df_metrics
# <style>.widget-dropdown select, .widget-dropdown .widget-readout { font-size: 14px !important; }</style>
# DEBUG: Running updated calculate_df_metrics
# VBox(children=(HTML(value='', layout=Layout(height='10px')), HTML(value='', layout=Layout(height='10px')), HBo…

# %% [markdown]
# ## III - Additional Notes
# - If you encounter any issues, verify the dependency versions in the `requirements.txt` file.
# - Ensure that the spaCy model is correctly downloaded (see the Introduction section).
# - For further questions, refer to the documentation in the GitHub repository's README.md.
